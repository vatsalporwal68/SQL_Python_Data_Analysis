# %% [markdown]
# # Orders Data Analysis
#
# This notebook covers downloading a dataset from Kaggle and performing data analysis.

# %%
# Install kaggle library using standard Python code to avoid notebook magic command syntax errors
import sys
import subprocess

subprocess.check_call([sys.executable, "-m", "pip", "install", "kaggle"])

# %%
# Note: To use the Kaggle API, you need a 'kaggle.json' file.
# It is already present at 'C:\Users\uvika\.kaggle\kaggle.json' on this system.

# %%
# Verify kaggle CLI installation using Python's subprocess module
import sys
import subprocess

result = subprocess.run([sys.executable, "-m", "kaggle", "--version"], capture_output=True, text=True, encoding="utf-8")
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)

# %%
# Example: Search for order/sales datasets using Python's subprocess module
import sys
import subprocess

result = subprocess.run([sys.executable, "-m", "kaggle", "datasets", "list", "-s", "orders"], capture_output=True, text=True, encoding="utf-8")
print(result.stdout)
